# %%
# Import the necessary libraries and load the dataset into Pandas DataFrame
import pandas as pd

hp = pd.read_csv('HousePrices_dataset.csv')
hp_copy = hp
hp
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# Perform basic data exploration and data cleaning if necessary
hp.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
hp.isna().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
hp.duplicated().sum()
# Out:
# 0

# %%
hp.tail()
# Out:
#                   date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09-07-2014 00:00  308166.6667         3       1.75         1510
# 4596  09-07-2014 00:00  534333.3333         3       2.50         1460
# 4597  09-07-2014 00:00  416904.1667         3       2.50         3010
# 4598  10-07-2014 00:00  203400.0000         4       2.00         2090
# 4599  10-07-2014 00:00  220600.0000         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0      1954          1979     501 N 143rd St    Seattle
# ...

# %%
hp.shape
# Out:
# (4600, 18)

# %%
hp.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
hp.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
hp.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %% [markdown]
# # Answer the key questions given below:

# %%
# Calculate the average house price using .mean()
avg_house_price = hp['price'].mean()
print('The average house price is ' + str(avg_house_price))
# Out:
# The average house price is 551962.9884730434

# %%
# Find the most common number of bedrooms and bathrooms
most_common_bedroom_number = hp['bedrooms'].mode()[0]
most_common_bathroom_number = hp['bathrooms'].mode()[0]
print('The most common bedroom number is ' + str((most_common_bedroom_number)))
print('The most common bathroom number is ' + str(most_common_bathroom_number))
# Out:
# The most common bedroom number is 3
# The most common bathroom number is 2.5

# %%
# Identify any correlation between the house price and other numeric features (e.g., sqft_living, waterfront, and view) using .corr() functions
numeric_features = ['sqft_living','waterfront', 'view']
correlation = hp[numeric_features + ['price']].corr(numeric_only = True)['price']
print(correlation)
# Out:
# sqft_living    0.430410
# waterfront     0.135648
# view           0.228504
# price          1.000000
# Name: price, dtype: float64

# %%
# Calculate the average price of waterfront and non-waterfront houses
waterfront_homes = hp[hp['waterfront'] == 1]
non_waterfront_homes = hp[hp['waterfront'] == 0]

avg_price_waterfront_homes = waterfront_homes['price'].mean()
avg_price_non_waterfront_homes = non_waterfront_homes['price'].mean()

print('The average price for waterfront homes is ' + str(avg_price_waterfront_homes))
print('The average price for non waterfront homes is ' + str(avg_price_non_waterfront_homes))
# Out:
# The average price for waterfront homes is 1451621.2121212122
# The average price for non waterfront homes is 545462.2831127654

# %%
# Determine the average price of houses with different numbers of floors
avg_price_by_floors = hp.groupby('floors')['price'].mean()
print(avg_price_by_floors)
# Out:
# floors
# 1.0    457278.687261
# 1.5    578692.700221
# 2.0    647985.230122
# 2.5    983863.390244
# 3.0    566157.587671
# 3.5    829250.000000
# Name: price, dtype: float64

# %%
# Analyze the average price based on the house condition
avg_price_by_condition = hp.groupby('condition')['price'].mean()
print(avg_price_by_condition)
# Out:
# condition
# 1    306633.333333
# 2    324373.750000
# 3    550111.516394
# 4    533647.286072
# 5    637041.322257
# Name: price, dtype: float64

# %% [markdown]
# # Visualize the data using only Pandas plotting capabilities to create:

# %%
# A histogram showing the distribution of house prices using .plot()
import matplotlib.pyplot as plt

hp['price'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Scatter plots to visualize the relationships between price and other numeric features using .plot()
hp.plot(kind = 'scatter', x = 'sqft_living', y = 'price', color = 'red')
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
hp.plot(kind = 'scatter', x = 'waterfront', y = 'price', color = 'blue')
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
hp.plot(kind = 'scatter', x = 'view', y = 'price', color = 'green')
# Out:
# <Axes: xlabel='view', ylabel='price'>

# %%
# A bar graph to count the occurrences of each city
count_of_city = hp['city'].value_counts()
count_of_city.plot(kind = 'bar', x = 'city', y = count_of_city)
# Out:
# <Axes: xlabel='city'>
