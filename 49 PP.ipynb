# %%
# Import the necessary libraries 
import pandas as pd

# Load the Titanic dataset from a CSV file
tt = pd.read_csv('titanic.csv')
tt_copy = tt
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Conduct exploratory data analysis using methods such as head(), tail(), describe(), and dtypes to examine the dataset
tt.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
tt.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
tt.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
tt.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
tt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
tt.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
tt.duplicated().sum()
# Out:
# 0

# %%
# Handle data indexing and manipulation using df.iloc[] and df.loc[] to access specific rows in the DataFrame: Provide 2 examples of each
tt_psa = tt[['PassengerId','Sex','Age']].head(10)
tt_psa
# Out:
#    PassengerId     Sex   Age
# 0          892    male  34.5
# 1          893  female  47.0
# 2          894    male  62.0
# 3          895    male  27.0
# 4          896  female  22.0
# 5          897    male  14.0
# 6          898  female  30.0
# 7          899    male  26.0
# 8          900  female  18.0
# 9          901    male  21.0

# %%
tt_psa.iloc[[0,2]]
# Out:
#    PassengerId   Sex   Age
# 0          892  male  34.5
# 2          894  male  62.0

# %%
tt_psa.iloc[[2,4,3]]
# Out:
#    PassengerId     Sex   Age
# 2          894    male  62.0
# 4          896  female  22.0
# 3          895    male  27.0

# %%
tt_pss = tt[['PassengerId','Survived','Sex']].head(10)
tt_pss
# Out:
#    PassengerId  Survived     Sex
# 0          892         0    male
# 1          893         1  female
# 2          894         0    male
# 3          895         0    male
# 4          896         1  female
# 5          897         0    male
# 6          898         1  female
# 7          899         0    male
# 8          900         1  female
# 9          901         0    male

# %%
tt_pss.loc[[4,5]]
# Out:
#    PassengerId  Survived     Sex
# 4          896         1  female
# 5          897         0    male

# %%
tt_pss.loc[[5,3,2]]
# Out:
#    PassengerId  Survived   Sex
# 5          897         0  male
# 3          895         0  male
# 2          894         0  male

# %%
# Filter the dataset based on Gender, Survival and save the resulting data to a new dataframe
# Convert column data types as necessary
tt_filter = tt.loc[(tt['Sex'] == 'female') & (tt['Survived'] == 1)]
tt_filter
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
new_tt = tt_filter.copy()

# %%
# Handle missing data using df.isnull().sum() to count null values in the DataFrame.  Fill missing values in the DataFrame using df.fillna().
print(tt.isnull().sum())
tt = tt.fillna('Unknown')
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# Conduct aggregate analysis using group-by operations: 2-3 aggregations
group1 = tt.groupby('Sex')['PassengerId'].count()
print(group1)

group2 = tt.groupby('Survived')['Pclass'].mean()
print(group2)
# Out:
# Sex
# female    152
# male      266
# Name: PassengerId, dtype: int64
# Survived
# 0    2.334586
# 1    2.144737
# Name: Pclass, dtype: float64

# %%
# Visualize the data using basic plotting techniques: 2 charts
tt
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex      Age  SibSp  \
# 0                                Kelly, Mr. James    male     34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female     47.0      1
# 2                       Myles, Mr. Thomas Francis    male     62.0      0
# 3                                Wirz, Mr. Albert    male     27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female     22.0      1
# ..                                            ...     ...      ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
count_of_passengerid = tt['Sex'].value_counts()
count_of_passengerid.plot(kind = 'bar', x = 'Sex', y = count_of_passengerid, color = ('blue', 'red'))
plt.ylabel('Count of Passenger ID')
plt.show()

# %%
avg_pclass = tt.groupby('Survived')['Pclass'].mean()
avg_pclass.plot(kind = 'bar', x = 'Sex', y = avg_pclass, color = ('orange', 'green'))
plt.ylabel('Avg Pclass')
plt.show()
